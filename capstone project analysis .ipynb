# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome(r"D:\flip robo\chromedriver.exe")

# %%
driver.get("https://www.imdb.com/search/title/?genres=action&sort=user_rating,desc&title_type=feature&num_votes=25000,&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=f11158cc-b50b-4c4d-b0a2-40b32863395b&pf_rd_r=XZ8X52H1R40B7KG5SNZ9&pf_rd_s=right-6&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_gnr_1")

# %%
p_name = []
start = 0
end = 35
for page in range (start,end):
    name = driver.find_elements (By.XPATH,'//h3[@class="lister-item-header"]')
    for i in name [0:100]:
        name = (i.text)
        p_name.append(name)
    next_button = driver.find_element (By.XPATH,'//a[@class="lister-page-next next-page"]')
    next_button.click()
    time.sleep(3)

# %%
m_names = []
years = []
s_nos = []

for i in p_name:
    a = i.split()[1:-1]
    b = i.split()[-1]
    b = b.replace("(", "")
    b = b.replace(")", "")
    c = " ".join(a)
    d = i.split()[0]
    m_names.append(c)
    years.append(b)
    s_nos.append(d.strip('.'))

# %%
geners = []
start = 0
end = 35
driver=webdriver.Chrome(r"D:\flip robo\chromedriver.exe")
driver.get("https://www.imdb.com/search/title/?genres=action&sort=user_rating,desc&title_type=feature&num_votes=25000,&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=f11158cc-b50b-4c4d-b0a2-40b32863395b&pf_rd_r=XZ8X52H1R40B7KG5SNZ9&pf_rd_s=right-6&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_gnr_1")
for page in range (start,end):
    title = driver.find_elements(By.XPATH,'//span[@class="genre"]')
    for i in title:
        i = i.text.strip()
        geners.append(str(i))
    next_button = driver.find_element (By.XPATH,'//a[@class="lister-page-next next-page"]')
    next_button.click()
    time.sleep(3)
geners
# Out:
# ['Action, Crime, Drama',
#  'Action, Adventure, Drama',
#  'Animation, Action, Adventure',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Sci-Fi',
#  'Action, Adventure, Fantasy',
#  'Action, Drama',
#  'Action, Sci-Fi',
#  'Action, Adventure, Fantasy',
#  'Action, Drama',
#  'Action, Drama, Mystery',
#  'Action, Drama, Mystery',
#  'Action, Adventure, Drama',
#  'Action, Crime, Drama',
#  'Action, Drama, Thriller',
#  'Animation, Action, Adventure',
#  'Action, Adventure',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Sci-Fi',
#  'Action, Drama, Mystery',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Crime',
#  'Action, Drama',
#  'Action, Drama',
#  'Action, Crime, Drama',
#  'Action, Adventure, Fantasy',
#  'Animation, Action, Adventure',
#  'Action, Adventure, Mystery',
#  'Action, Biography, Drama',
#  'Action, Adventure, Drama',
#  'Action, Crime, Drama',
#  'Action, Crime, Thriller',
# ...

# %%
import pandas as pd
df4 = pd.DataFrame({"Geners":geners})

df4[["Geners-1","Geners-2","Geners-3"]] = df4.Geners.str.split(",", expand = True)
df4.drop("Geners",axis=1,inplace=True)

# %%
from tqdm import tqdm

# %%
votess = []
start = 0
end = 35
driver=webdriver.Chrome(r"D:\flip robo\chromedriver.exe")
driver.get("https://www.imdb.com/search/title/?genres=action&sort=user_rating,desc&title_type=feature&num_votes=25000,&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=f11158cc-b50b-4c4d-b0a2-40b32863395b&pf_rd_r=XZ8X52H1R40B7KG5SNZ9&pf_rd_s=right-6&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_gnr_1")
for page in tqdm(range (start,end)):
    title = driver.find_elements(By.XPATH,'//p[@class="sort-num_votes-visible"]')
    for i in title:
        i = i.text.strip()
        votess.append(i)
    next_button = driver.find_element(By.XPATH,'//a[@class="lister-page-next next-page"]')
    next_button.click()
    time.sleep(3)
vottep = []
for i in votess:
    i=(i.split()[1])
    vottep.append((i))
# Out:
# 100%|██████████| 35/35 [04:26<00:00,  7.61s/it]

# %%
gross_incom = []
for i in votess:
    i=(i.split()[-1])
    gross_incom.append((i))

# %%
gross_incom
# Out:
# ['$534.86M',
#  '$377.85M',
#  '200,597',
#  '$292.58M',
#  '$315.54M',
#  '$342.55M',
#  '$171.48M',
#  '$290.48M',
#  '120,247',
#  '$204.84M',
#  '$322.74M',
#  '$0.27M',
#  '62,713',
#  '61,852',
#  '$187.71M',
#  '$19.50M',
#  '$448.14M',
#  '$858.37M',
#  '$190.24M',
#  '$248.16M',
#  '$85.16M',
#  '$0.71M',
#  '$678.82M',
#  '36,986',
#  '31,652',
#  '$718.73M',
#  '$67.44M',
#  '$13.28M',
#  '$309.13M',
#  '$2.38M',
#  '$12.39M',
#  '97,259',
#  '65,139',
#  '$6.60M',
#  '125,825',
#  '47,652',
#  '$206.85M',
#  '$804.75M',
#  '$402.45M',
#  '$159.23M',
#  '$197.17M',
#  '$70.10M',
#  '$70.51M',
#  '$83.01M',
#  '$4.14M',
#  '$47.70M',
#  '100,118',
#  '127,154',
#  '92,906',
#  '$20.19M',
#  '$0.98M',
#  '$4.19M',
#  '$3.51M',
#  '48,380',
#  '109,405',
#  '$0.04M',
#  '$154.06M',
#  '$305.41M',
#  '$38.40M',
#  '$32.87M',
#  '$117.62M',
#  '$226.28M',
#  '$13.66M',
#  '$26.95M',
#  '$3.90M',
#  '$217.58M',
#  '$23.16M',
#  '59,753',
#  '40,811',
#  '34,599',
#  '$1.03M',
# ...

# %%
gross_incme = []
for i in gross_incom:
    j = i.replace('$','')
    gross_incme.append(j)

# %%
gross_incme
# Out:
# ['534.86M',
#  '377.85M',
#  '200,597',
#  '292.58M',
#  '315.54M',
#  '342.55M',
#  '171.48M',
#  '290.48M',
#  '120,247',
#  '204.84M',
#  '322.74M',
#  '0.27M',
#  '62,713',
#  '61,852',
#  '187.71M',
#  '19.50M',
#  '448.14M',
#  '858.37M',
#  '190.24M',
#  '248.16M',
#  '85.16M',
#  '0.71M',
#  '678.82M',
#  '36,986',
#  '31,652',
#  '718.73M',
#  '67.44M',
#  '13.28M',
#  '309.13M',
#  '2.38M',
#  '12.39M',
#  '97,259',
#  '65,139',
#  '6.60M',
#  '125,825',
#  '47,652',
#  '206.85M',
#  '804.75M',
#  '402.45M',
#  '159.23M',
#  '197.17M',
#  '70.10M',
#  '70.51M',
#  '83.01M',
#  '4.14M',
#  '47.70M',
#  '100,118',
#  '127,154',
#  '92,906',
#  '20.19M',
#  '0.98M',
#  '4.19M',
#  '3.51M',
#  '48,380',
#  '109,405',
#  '0.04M',
#  '154.06M',
#  '305.41M',
#  '38.40M',
#  '32.87M',
#  '117.62M',
#  '226.28M',
#  '13.66M',
#  '26.95M',
#  '3.90M',
#  '217.58M',
#  '23.16M',
#  '59,753',
#  '40,811',
#  '34,599',
#  '1.03M',
#  '80,609',
#  '70,045',
#  '8.18M',
#  '57,473',
# ...

# %%
gross_income = []
for i in gross_incme:
    f = i.replace(',','')
    gross_income.append(f)

# %%
def convert_to_single_int(value_str):
    if value_str[-1] == 'M':
        return int(float(value_str[:-1]) * 1000000)
    else:
        return int(value_str)

# Assuming 'my_list' is your list containing the values
#my_list = ['45.25M', '425612', '100M', '250M', '72.9M', '900']

# Convert values with 'M' suffix to single integers representing millions
converted_list = [convert_to_single_int(value) for value in gross_income]
# Out:
# [534860000, 377850000, 200597, 292580000, 315540000, 342550000, 171480000, 290480000, 120247, 204840000, 322740000, 270000, 62713, 61852, 187710000, 19500000, 448140000, 858370000, 190240000, 248160000, 85160000, 710000, 678820000, 36986, 31652, 718730000, 67440000, 13280000, 309130000, 2380000, 12390000, 97259, 65139, 6600000, 125825, 47652, 206850000, 804750000, 402450000, 159230000, 197170000, 70100000, 70510000, 83010000, 4139999, 47700000, 100118, 127154, 92906, 20190000, 980000, 4190000, 3510000, 48380, 109405, 40000, 154060000, 305410000, 38400000, 32869999, 117620000, 226280000, 13660000, 26950000, 3900000, 217580000, 23160000, 59753, 40811, 34599, 1030000, 80609, 70045, 8180000, 57473, 30878, 26364, 28521, 36122, 259888, 116908, 108330000, 333180000, 92050000, 183640000, 363070000, 623280000, 167450000, 261440000, 66209999, 550000, 227470000, 229705, 170000, 36008, 10000, 6740000, 39822, 100000, 900000, 1110000, 63582, 54420, 26498, 34566, 45998, 760510000, 100210000, 420522
# ...

# %%
votte = []
for i in vottep:
    j = i.replace(',','')
    votte.append(j)

# %%
rating = []
start = 0
end = 35
driver=webdriver.Chrome(r"D:\flip robo\chromedriver.exe")
driver.get("https://www.imdb.com/search/title/?genres=action&sort=user_rating,desc&title_type=feature&num_votes=25000,&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=f11158cc-b50b-4c4d-b0a2-40b32863395b&pf_rd_r=XZ8X52H1R40B7KG5SNZ9&pf_rd_s=right-6&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_gnr_1")
for page in tqdm(range (start,end)):
    title = driver.find_elements(By.XPATH,'//div[@class="inline-block ratings-imdb-rating"]')
    for i in title:
        i = i.text.strip()
        rating.append(float(i))
    next_button = driver.find_element(By.XPATH,'//a[@class="lister-page-next next-page"]')
    next_button.click()
# Out:
# 100%|██████████| 35/35 [02:23<00:00,  4.10s/it]

# %%
dur = []
start = 0
end = 35
driver=webdriver.Chrome(r"D:\flip robo\chromedriver.exe")
driver.get("https://www.imdb.com/search/title/?genres=action&sort=user_rating,desc&title_type=feature&num_votes=25000,&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=f11158cc-b50b-4c4d-b0a2-40b32863395b&pf_rd_r=XZ8X52H1R40B7KG5SNZ9&pf_rd_s=right-6&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_gnr_1")
for page in tqdm(range (start,end)):
    title = driver.find_elements(By.XPATH,'//span[@class="runtime"]')
    for i in title:
        i = i.text.strip().replace("min"," ")
        dur.append(int(i))
    next_button = driver.find_element(By.XPATH,'//a[@class="lister-page-next next-page"]')
    next_button.click()
    time.sleep(3)
# Out:
# 100%|██████████| 35/35 [04:04<00:00,  6.99s/it]

# %%
certificate = []
start = 0
end = 35

driver=webdriver.Chrome(r"D:\flip robo\chromedriver.exe")
driver.get("https://www.imdb.com/search/title/?genres=action&sort=user_rating,desc&title_type=feature&num_votes=25000,&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=f11158cc-b50b-4c4d-b0a2-40b32863395b&pf_rd_r=XZ8X52H1R40B7KG5SNZ9&pf_rd_s=right-6&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_gnr_1")
for page in tqdm(range (start,end)):
    title = driver.find_elements(By.XPATH,"/html/body/div/div/div/div/div/div/div/div/div/div/p[1]")
    for i in title:
        i = i.text
        j = i.split("|")
        if len(j) == 2:
            certificate.append("Blank")
        else:
            certificate.append(j[0].strip())
certificate
# Out:
# 100%|██████████| 35/35 [00:28<00:00,  1.24it/s]
# ['PG-13',
#  'PG-13',
#  'PG',
#  'PG-13',
#  'PG-13',
#  'PG-13',
#  'R',
#  'PG',
#  'TV-MA',
#  'R',
#  'PG',
#  'Not Rated',
#  'Not Rated',
#  'U',
#  'R',
#  'R',
#  'PG-13',
#  'PG-13',
#  'PG',
#  'PG',
#  'R',
#  'R',
#  'PG-13',
#  'Not Rated',
#  'Not Rated',
#  'PG-13',
#  'R',
#  'Approved',
#  'PG',
#  'PG-13',
#  'Not Rated',
#  'Not Rated',
#  'UA',
#  'Not Rated',
#  'TV-14',
#  'Not Rated',
#  'PG-13',
#  'PG-13',
#  'PG-13',
#  'R',
#  'PG-13',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'Not Rated',
#  'Not Rated',
#  'Not Rated',
#  'Not Rated',
#  'PG-13',
#  'PG-13',
#  'PG',
#  'PG-13',
#  'PG-13',
#  'PG-13',
#  'R',
#  'PG',
#  'TV-MA',
#  'R',
#  'PG',
#  'Not Rated',
#  'Not Rated',
#  'U',
#  'R',
#  'R',
#  'PG-13',
#  'PG-13',
#  'PG',
#  'PG',
#  'R',
#  'R',
#  'PG-13',
#  'Not Rated',
#  'Not Rated',
#  'PG-13',
#  'R',
#  'Approved',
#  'PG',
#  'PG-13',
#  'Not Rated',
#  'Not Rated',
#  'UA',
# ...

# %%
diectors = []
start = 0
end = 35
driver=webdriver.Chrome(r"D:\flip robo\chromedriver.exe")
driver.get("https://www.imdb.com/search/title/?genres=action&sort=user_rating,desc&title_type=feature&num_votes=25000,&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=f11158cc-b50b-4c4d-b0a2-40b32863395b&pf_rd_r=XZ8X52H1R40B7KG5SNZ9&pf_rd_s=right-6&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_gnr_1")
for page in tqdm(range (start,end)):
    tts = driver.find_elements(By.XPATH,'//p[@class=""]')
    for i in tts:
        i = i.text.split("|")[0].replace("Director:", "")
        i = i.replace("Directors:", "")
        diectors.append(i.strip())
    next_button = driver.find_element(By.XPATH,'//a[@class="lister-page-next next-page"]')
    next_button.click()
# Out:
# 100%|██████████| 35/35 [02:24<00:00,  4.12s/it]

# %%
len(diectors)
# Out:
# 1750

# %%
import pandas as pd
df_director = pd.DataFrame({"Directors":diectors})

df_director[["Director-1","Director-2","Director-3","Director-4","Director-5","Director-6"]] = df_director.Directors.str.split(",", expand = True)
df_director.drop("Directors",axis=1,inplace=True)

# %%
stars = []
start = 0
end = 35
driver=webdriver.Chrome(r"D:\flip robo\chromedriver.exe")
driver.get("https://www.imdb.com/search/title/?genres=action&sort=user_rating,desc&title_type=feature&num_votes=25000,&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=f11158cc-b50b-4c4d-b0a2-40b32863395b&pf_rd_r=XZ8X52H1R40B7KG5SNZ9&pf_rd_s=right-6&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_gnr_1")
for page in tqdm(range (start,end)):
    tts = driver.find_elements(By.XPATH,'//p[@class=""]')
    for i in tts:
        i = i.text.split("|")[-1].replace("Stars:"," ")
        i = i.replace("Stars:", " ")
        stars.append(i.strip())
# Out:
# 100%|██████████| 35/35 [00:28<00:00,  1.22it/s]

# %%
import pandas as pd
df1 = pd.DataFrame({"Stars":stars})

df1[["Stars-1","Stars-2","Stars-3","Stars-4"]] = df1.Stars.str.split(",", expand = True)
df1.drop("Stars",axis=1,inplace=True)

# %%
Certifict = []
start = 0
end = 35
driver=webdriver.Chrome(r"D:\flip robo\chromedriver.exe")
driver.get("https://www.imdb.com/search/title/?genres=action&sort=user_rating,desc&title_type=feature&num_votes=25000,&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=f11158cc-b50b-4c4d-b0a2-40b32863395b&pf_rd_r=XZ8X52H1R40B7KG5SNZ9&pf_rd_s=right-6&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_gnr_1")
for page in tqdm(range (start,end)):
    title = driver.find_elements(By.XPATH,'//p[@class="text-muted "]')
    for i in title:
        i = i.text
        i = i.split("|")
        if len(i) == 2:
            Certifict.append("Blank")
        else:
            Certifict.append(i[0])
    next_button = driver.find_element(By.XPATH,'//a[@class="lister-page-next next-page"]')
    next_button.click()
# Out:
# 100%|██████████| 35/35 [02:37<00:00,  4.49s/it]

# %%
mt = []
start = 0
end = 35

driver=webdriver.Chrome(r"D:\flip robo\chromedriver.exe")
driver.get("https://www.imdb.com/search/title/?genres=action&sort=user_rating,desc&title_type=feature&num_votes=25000,&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=f11158cc-b50b-4c4d-b0a2-40b32863395b&pf_rd_r=XZ8X52H1R40B7KG5SNZ9&pf_rd_s=right-6&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_gnr_1")
for page in tqdm(range (start,end)):
    title = driver.find_elements(By.XPATH,'//div[@class="ratings-bar"]')
    for i in title:
        i = i.text.split()
        if len(i) == 3:
            mt.append("np.nan")
        else:
            mt.append(int(i[3]))
    next_button = driver.find_element(By.XPATH,'//a[@class="lister-page-next next-page"]')
    next_button.click()
# Out:
# 100%|██████████| 35/35 [02:33<00:00,  4.40s/it]

# %%
table_3 = pd.DataFrame({'S no':s_nos,'Movie':m_names})
table_3
# Out:
#        S no                                              Movie
# 0         1                                    The Dark Knight
# 1         2      The Lord of the Rings: The Return of the King
# 2         3                Spider-Man: Across the Spider-Verse
# 3         4                                          Inception
# 4         5  The Lord of the Rings: The Fellowship of the Ring
# ...     ...                                                ...
# 1745  1,746                                     Batman & Robin
# 1746  1,747      In the Name of the King: A Dungeon Siege Tale
# 1747  1,748                                       The Avengers
# 1748  1,749        The Adventures of Sharkboy and Lavagirl 3-D
# 1749  1,750                   Superman IV: The Quest for Peace
#
# [1750 rows x 2 columns]

# %%
df4 ['S no'] = table_3['S no'].to_list()

# %%
df4
# Out:
#        Geners-1    Geners-2    Geners-3   S no
# 0        Action       Crime       Drama      1
# 1        Action   Adventure       Drama      2
# 2     Animation      Action   Adventure      3
# 3        Action   Adventure      Sci-Fi      4
# 4        Action   Adventure       Drama      5
# ...         ...         ...         ...    ...
# 1745     Action      Sci-Fi        None  1,746
# 1746     Action   Adventure     Fantasy  1,747
# 1747     Action   Adventure      Sci-Fi  1,748
# 1748     Action   Adventure      Comedy  1,749
# 1749     Action   Adventure      Sci-Fi  1,750
#
# [1750 rows x 4 columns]

# %%
table_3 = table_3.merge(df4, how = 'right')
table_3
# Out:
#        S no                                              Movie   Geners-1  \
# 0         1                                    The Dark Knight     Action
# 1         2      The Lord of the Rings: The Return of the King     Action
# 2         3                Spider-Man: Across the Spider-Verse  Animation
# 3         4                                          Inception     Action
# 4         5  The Lord of the Rings: The Fellowship of the Ring     Action
# ...     ...                                                ...        ...
# 1745  1,746                                     Batman & Robin     Action
# 1746  1,747      In the Name of the King: A Dungeon Siege Tale     Action
# 1747  1,748                                       The Avengers     Action
# 1748  1,749        The Adventures of Sharkboy and Lavagirl 3-D     Action
# 1749  1,750                   Superman IV: The Quest for Peace     Action
#
#         Geners-2    Geners-3
# 0          Crime       Drama
# ...

# %%
df1
# Out:
#                 Stars-1                Stars-2               Stars-3  \
# 0        Christian Bale           Heath Ledger         Aaron Eckhart
# 1           Elijah Wood        Viggo Mortensen          Ian McKellen
# 2         Shameik Moore       Hailee Steinfeld     Brian Tyree Henry
# 3     Leonardo DiCaprio   Joseph Gordon-Levitt           Elliot Page
# 4           Elijah Wood           Ian McKellen         Orlando Bloom
# ...                 ...                    ...                   ...
# 1745      Natsuki Hanae             Akari Kitô   Yoshitsugu Matsuoka
# 1746     Manoj Bajpayee    Nawazuddin Siddiqui      Tigmanshu Dhulia
# 1747     Toshirô Mifune            Eijirô Tôno       Tatsuya Nakadai
# 1748               Yash        Srinidhi Shetty      Ramachandra Raju
# 1749            Prabhas         Rana Daggubati        Anushka Shetty
#
#                  Stars-4   S no
# 0          Michael Caine      1
# 1          Orlando Bloom      2
# 2      Luna Lauren Velez      3
# ...

# %%
df1 ['S no'] = table_3['S no'].to_list()

# %%
table_3 = table_3.merge(df1, how = 'right')
table_3
# Out:
#        S no                                              Movie   Geners-1  \
# 0         1                                    The Dark Knight     Action
# 1         2      The Lord of the Rings: The Return of the King     Action
# 2         3                Spider-Man: Across the Spider-Verse  Animation
# 3         4                                          Inception     Action
# 4         5  The Lord of the Rings: The Fellowship of the Ring     Action
# ...     ...                                                ...        ...
# 1745  1,746                                     Batman & Robin     Action
# 1746  1,747      In the Name of the King: A Dungeon Siege Tale     Action
# 1747  1,748                                       The Avengers     Action
# 1748  1,749        The Adventures of Sharkboy and Lavagirl 3-D     Action
# 1749  1,750                   Superman IV: The Quest for Peace     Action
#
#         Geners-2    Geners-3            Stars-1                Stars-2  \
# ...

# %%
others = pd.DataFrame({'S no':s_nos,'Vottes':votte,'Gross collection':converted_list,'Certification':Certifict})

# %%
others['Gross collection'] = pd.to_numeric(others['Gross collection'], errors='coerce')


table_3 = table_3.merge(others, how='right')

# %%
table_3
# Out:
#        S no                                              Movie   Geners-1  \
# 0         1                                    The Dark Knight     Action
# 1         2      The Lord of the Rings: The Return of the King     Action
# 2         3                Spider-Man: Across the Spider-Verse  Animation
# 3         4                                          Inception     Action
# 4         5  The Lord of the Rings: The Fellowship of the Ring     Action
# ...     ...                                                ...        ...
# 1745  1,746                                     Batman & Robin     Action
# 1746  1,747      In the Name of the King: A Dungeon Siege Tale     Action
# 1747  1,748                                       The Avengers     Action
# 1748  1,749        The Adventures of Sharkboy and Lavagirl 3-D     Action
# 1749  1,750                   Superman IV: The Quest for Peace     Action
#
#         Geners-2    Geners-3            Stars-1                Stars-2  \
# ...

# %% [markdown]
# # 2 ND COLUMN

# %%
df_director
# Out:
#                Director-1    Director-2           Director-3 Director-4  \
# 0       Christopher Nolan          None                 None       None
# 1           Peter Jackson          None                 None       None
# 2      Joaquim Dos Santos   Kemp Powers   Justin K. Thompson       None
# 3       Christopher Nolan          None                 None       None
# 4           Peter Jackson          None                 None       None
# ...                   ...           ...                  ...        ...
# 1745      Joel Schumacher          None                 None       None
# 1746             Uwe Boll          None                 None       None
# 1747  Jeremiah S. Chechik          None                 None       None
# 1748     Robert Rodriguez          None                 None       None
# 1749      Sidney J. Furie          None                 None       None
#
#      Director-5 Director-6   S no
# 0          None       None      1
# ...

# %%
ddd = pd.DataFrame({'S no':s_nos,})

# %%
df_director ['S no'] = ddd['S no'].to_list()

# %%
table_1 = pd.DataFrame({'S no':s_nos,'Movie':m_names,})
table_1
# Out:
#        S no                                              Movie
# 0         1                                    The Dark Knight
# 1         2      The Lord of the Rings: The Return of the King
# 2         3                Spider-Man: Across the Spider-Verse
# 3         4                                          Inception
# 4         5  The Lord of the Rings: The Fellowship of the Ring
# ...     ...                                                ...
# 1745  1,746                                     Batman & Robin
# 1746  1,747      In the Name of the King: A Dungeon Siege Tale
# 1747  1,748                                       The Avengers
# 1748  1,749        The Adventures of Sharkboy and Lavagirl 3-D
# 1749  1,750                   Superman IV: The Quest for Peace
#
# [1750 rows x 2 columns]

# %%
table_1 = table_1.merge(df_director, how = 'right')
table_1
# Out:
#        S no                                              Movie  \
# 0         1                                    The Dark Knight
# 1         2      The Lord of the Rings: The Return of the King
# 2         3                Spider-Man: Across the Spider-Verse
# 3         4                                          Inception
# 4         5  The Lord of the Rings: The Fellowship of the Ring
# ...     ...                                                ...
# 1745  1,746                                     Batman & Robin
# 1746  1,747      In the Name of the King: A Dungeon Siege Tale
# 1747  1,748                                       The Avengers
# 1748  1,749        The Adventures of Sharkboy and Lavagirl 3-D
# 1749  1,750                   Superman IV: The Quest for Peace
#
#                Director-1    Director-2           Director-3 Director-4  \
# 0       Christopher Nolan          None                 None       None
# ...

# %%
others_2 = pd.DataFrame({'S no':s_nos,'Duration':dur,'Year':years,'Rating':rating,'Meta_score':mt})

# %%
table_1 = table_1.merge(others_2, how = 'right')
table_1
# Out:
#        S no                                              Movie  \
# 0         1                                    The Dark Knight
# 1         2      The Lord of the Rings: The Return of the King
# 2         3                Spider-Man: Across the Spider-Verse
# 3         4                                          Inception
# 4         5  The Lord of the Rings: The Fellowship of the Ring
# ...     ...                                                ...
# 1745  1,746                                     Batman & Robin
# 1746  1,747      In the Name of the King: A Dungeon Siege Tale
# 1747  1,748                                       The Avengers
# 1748  1,749        The Adventures of Sharkboy and Lavagirl 3-D
# 1749  1,750                   Superman IV: The Quest for Peace
#
#                Director-1    Director-2           Director-3 Director-4  \
# 0       Christopher Nolan          None                 None       None
# ...

# %%
table_1.to_csv("table_1.csv", index=False)

# %%
table_3.to_csv('table_3.csv',index=False)

# %% [markdown]
# # PHASE 2

# %% [markdown]
# # NOW SQL DBMS TASK

# %%
import sqlite3
dbcon = sqlite3.connect("movie_database.db")

# %%
cur = dbcon.cursor()
df_table1 = pd.read_csv('table_1.csv')
df_table2 = pd.read_csv('table_3.csv')

# %%
df_table2
# Out:
#        S no                                              Movie   Geners-1  \
# 0         1                                    The Dark Knight     Action
# 1         2      The Lord of the Rings: The Return of the King     Action
# 2         3                Spider-Man: Across the Spider-Verse  Animation
# 3         4                                          Inception     Action
# 4         5  The Lord of the Rings: The Fellowship of the Ring     Action
# ...     ...                                                ...        ...
# 1745  1,746                                     Batman & Robin     Action
# 1746  1,747      In the Name of the King: A Dungeon Siege Tale     Action
# 1747  1,748                                       The Avengers     Action
# 1748  1,749        The Adventures of Sharkboy and Lavagirl 3-D     Action
# 1749  1,750                   Superman IV: The Quest for Peace     Action
#
#         Geners-2    Geners-3            Stars-1                Stars-2  \
# ...

# %%
df_table1.to_sql('table1_data', conn, if_exists='replace', index=False)
df_table2.to_sql('table2_data', conn, if_exists='replace', index=False)
# Out:
# 1750

# %% [markdown]
# # table 1 quiry

# %%
query1 = """
SELECT * FROM table1_data
WHERE "Director-1" IN ('Christopher Nolan', 'Matt Reeves')
OR "Director-2" IN ('Christopher Nolan', 'Matt Reeves') 
OR "Director-3" IN ('Christopher Nolan', 'Matt Reeves')
OR "Director-4" IN ('Christopher Nolan', 'Matt Reeves')
OR "Director-5" IN ('Christopher Nolan', 'Matt Reeves')
OR "Director-6" IN ('Christopher Nolan', 'Matt Reeves');
"""
result2 = pd.read_sql_query(query1, conn)
print("Query 1:")
print(result2)
# Out:
# Query 1:
#   S no                           Movie         Director-1 Director-2  \
# 0    1                 The Dark Knight  Christopher Nolan       None
# 1    4                       Inception  Christopher Nolan       None
# 2   17           The Dark Knight Rises  Christopher Nolan       None
# 3   37                   Batman Begins  Christopher Nolan       None
# 4  130                         Dunkirk  Christopher Nolan       None
# 5  132                      The Batman        Matt Reeves       None
# 6  226  Dawn of the Planet of the Apes        Matt Reeves       None
# 7  312  War for the Planet of the Apes        Matt Reeves       None
# 8  325                           Tenet  Christopher Nolan       None
# 9  521                     Cloverfield        Matt Reeves       None
#
#   Director-3 Director-4 Director-5 Director-6  Duration  Year  Rating  \
# 0       None       None       None       None       152  2008     9.0
# ...

# %%
query2 = """
SELECT * FROM table1_data
WHERE Duration BETWEEN 140 AND 190;
"""
result2 = pd.read_sql_query(query2, dbcon)
print("Query 2:")
print(result2)
# Out:
# Query 2:
#       S no                                              Movie  \
# 0        1                                    The Dark Knight
# 1        3                Spider-Man: Across the Spider-Verse
# 2        4                                          Inception
# 3        5  The Lord of the Rings: The Fellowship of the Ring
# 4        6              The Lord of the Rings: The Two Towers
# ..     ...                                                ...
# 198  1,698                                          Shamshera
# 199  1,707                                             Ra.One
# 200  1,709                                             Bharat
# 201  1,719                          Kisi Ka Bhai Kisi Ki Jaan
# 202  1,722                                           Shehzada
#
#              Director-1    Director-2           Director-3 Director-4  \
# 0     Christopher Nolan          None                 None       None
# ...

# %%
query3 = """
SELECT * FROM table1_data
WHERE Rating > 7
ORDER BY Rating ASC;
"""
result3 = pd.read_sql_query(query3, dbcon)
print("Query 3:")
print(result3)
# Out:
# Query 3:
#     S no                                              Movie  \
# 0    435                                Mission: Impossible
# 1    436                                          The Mummy
# 2    437                                       Man of Steel
# 3    438                                      American Made
# 4    439                                           WarGames
# ..   ...                                                ...
# 488    5  The Lord of the Rings: The Fellowship of the Ring
# 489    6              The Lord of the Rings: The Two Towers
# 490    3                Spider-Man: Across the Spider-Verse
# 491    1                                    The Dark Knight
# 492    2      The Lord of the Rings: The Return of the King
#
#              Director-1    Director-2           Director-3 Director-4  \
# 0        Brian De Palma          None                 None       None
# 1       Stephen Sommers          None                 None       None
# ...

# %%
query4 = """
SELECT "Movie" FROM table1_data
ORDER BY "Movie" DESC;
"""
result4 = pd.read_sql_query(query4, dbcon)
print("Query 4:")
print(result4)
# Out:
# Query 4:
#                            Movie
# 0                       Æon Flux
# 1        xXx: State of the Union
# 2     xXx: Return of Xander Cage
# 3                            xXx
# 4                    Zoolander 2
# ...                          ...
# 1745                   12 Strong
# 1746                   12 Rounds
# 1747                   10,000 BC
# 1748                         '71
# 1749                      #Alive
#
# [1750 rows x 1 columns]

# %%
query5 = """
SELECT "Movie","Rating" FROM table1_data
WHERE "Movie" LIKE 'P%' AND Rating > 7;
"""
result5 = pd.read_sql_query(query5, dbcon)
print("Query 5:")
print(result5)
# Out:
# Query 5:
#                                                 Movie  Rating
# 0                                   Princess Mononoke     8.3
# 1                                    Paan Singh Tomar     8.2
# 2   Pirates of the Caribbean: The Curse of the Bla...     8.1
# 3                                            Predator     7.8
# 4                           Pushpa: The Rise - Part 1     7.6
# 5                             Ponniyin Selvan: Part I     7.6
# 6                                        Police Story     7.5
# 7          Pirates of the Caribbean: Dead Man's Chest     7.4
# 8                                  Predestination (I)     7.4
# 9                                        Patriots Day     7.3
# 10                                        Point Break     7.2
# 11                                           Prey (I)     7.1
# 12           Pirates of the Caribbean: At World's End     7.1
# 13                                        Payback (I)     7.1

# %% [markdown]
# # table 2 quiry

# %%
query1 = """
SELECT "Movie" FROM table2_data
WHERE "Stars-1" LIKE ('Arnold Schwarzenegger')
OR "Stars-2" LIKE ('Arnold Schwarzenegger')
OR "Stars-3" LIKE ('Arnold Schwarzenegger')
OR "Stars-4" LIKE ('Arnold Schwarzenegger') ORDER BY "Movie";
"""
result1 = pd.read_sql_query(query1, conn)
print("Query 1:")
print(result1)
# Out:
# Query 1:
#                                              Movie
# 0                                        10,000 BC
# 1                                     Babylon A.D.
# 2                     Batman: Mask of the Phantasm
# 3                                     Blade Runner
# 4                                       Colombiana
# 5                                   Demolition Man
# 6                                        Desperado
# 7                               Enemy at the Gates
# 8                                 Escape from L.A.
# 9                               Executive Decision
# 10                                        Iron Man
# 11                                 Kung Fu Panda 2
# 12                                          Legion
# 13                                  Man of Tai Chi
# 14                                    Passenger 57
# 15  Pokémon: The First Movie - Mewtwo Strikes Back
# 16                                        Red Dawn
# ...

# %%
query2 = """
SELECT *
FROM table2_data
WHERE Vottes = (SELECT MAX(Vottes) FROM table2_data);
"""
result2 = pd.read_sql_query(query2, conn)
print("Query 2:")
print(result2)
# Out:
# Query 2:
#   S no            Movie Geners-1 Geners-2 Geners-3         Stars-1  \
# 0    1  The Dark Knight   Action    Crime    Drama  Christian Bale
#
#          Stars-2         Stars-3         Stars-4   Vottes  Gross collection  \
# 0   Heath Ledger   Aaron Eckhart   Michael Caine  2757417         534860000
#
#   Certification
# 0        PG-13

# %%
query2 = """
SELECT "Vottes" FROM table2_data ORDER BY "Vottes";
"""
result2 = pd.read_sql_query(query2, conn)
print("Query 2:")
print(result2)
# Out:
# Query 2:
#        Vottes
# 0       25002
# 1       25032
# 2       25039
# 3       25049
# 4       25049
# ...       ...
# 1745  1905575
# 1746  1933786
# 1747  1978134
# 1748  2447920
# 1749  2757417
#
# [1750 rows x 1 columns]

# %%
query3 = """
SELECT "Movie"
FROM table2_data
ORDER BY "Gross collection" DESC;
"""
result3 = pd.read_sql_query(query3, conn)
print("Query 3:")
print(result3)
# Out:
# Query 3:
#                                            Movie
# 0     Star Wars: Episode VII - The Force Awakens
# 1                              Avengers: Endgame
# 2                        Spider-Man: No Way Home
# 3                                         Avatar
# 4                              Top Gun: Maverick
# ...                                          ...
# 1745                           Mutant Chronicles
# 1746                   Knockin' on Heaven's Door
# 1747                                Son of a Gun
# 1748                               The Condemned
# 1749                                   Wild Card
#
# [1750 rows x 1 columns]

# %%
query4 = """
SELECT "Movie", "Gross collection"
FROM table2_data
WHERE "Stars-1" IN ('Arnold Schwarzenegger')
OR "Stars-2" IN ('Arnold Schwarzenegger')
OR "Stars-3" IN ('Arnold Schwarzenegger')
OR "Stars-4" IN ('Arnold Schwarzenegger');
"""
result4 = pd.read_sql_query(query4, conn)
print("Query 4:")
print(result4)
# Out:
# Query 4:
#                                              Movie  Gross collection
# 0                       Terminator 2: Judgment Day         204840000
# 1                                     Blade Runner          32869999
# 2                                         Iron Man         318410000
# 3                     Batman: Mask of the Phantasm           5620000
# 4                                          RoboCop          53420000
# 5                               Enemy at the Gates          51400000
# 6                                 X2: X-Men United         214950000
# 7                         The Adventures of Tintin          77590000
# 8                                  Kung Fu Panda 2         165250000
# 9                                        Desperado          25630000
# 10                                        Stargate          71570000
# 11                                          Sultan           6200000
# ...

# %%
query5 = """
SELECT * FROM table2_data
WHERE "Geners-1" IN ('Comedy','Action')
OR "Geners-2" IN ('Comedy','Action')
OR "Geners-3" IN ('Comedy','Action');
"""
result5 = pd.read_sql_query(query5, conn)
print("Query 5:")
print(result5)
# Out:
# Query 5:
#        S no                                              Movie Geners-1  \
# 0         1                                    The Dark Knight   Action
# 1         2      The Lord of the Rings: The Return of the King   Action
# 2         4                                          Inception   Action
# 3         5  The Lord of the Rings: The Fellowship of the Ring   Action
# 4         6              The Lord of the Rings: The Two Towers   Action
# ...     ...                                                ...      ...
# 1674  1,746                                     Batman & Robin   Action
# 1675  1,747      In the Name of the King: A Dungeon Siege Tale   Action
# 1676  1,748                                       The Avengers   Action
# 1677  1,749        The Adventures of Sharkboy and Lavagirl 3-D   Action
# 1678  1,750                   Superman IV: The Quest for Peace   Action
#
#         Geners-2  Geners-3            Stars-1                Stars-2  \
# ...

# %% [markdown]
# # sub query

# %%
query1 = """
SELECT *
FROM table1_data 
JOIN table2_data ON table1_data."Movie" = table2_data."Movie";
"""
result1 = pd.read_sql_query(query1, conn)
print("Query 1:")
print(result1)
# Out:
# Query 1:
#        S no                                              Movie  \
# 0         1                                    The Dark Knight
# 1         2      The Lord of the Rings: The Return of the King
# 2         3                Spider-Man: Across the Spider-Verse
# 3         4                                          Inception
# 4         5  The Lord of the Rings: The Fellowship of the Ring
# ...     ...                                                ...
# 1799  1,747      In the Name of the King: A Dungeon Siege Tale
# 1800  1,748                                       The Avengers
# 1801  1,748                                       The Avengers
# 1802  1,749        The Adventures of Sharkboy and Lavagirl 3-D
# 1803  1,750                   Superman IV: The Quest for Peace
#
#                Director-1    Director-2           Director-3 Director-4  \
# 0       Christopher Nolan          None                 None       None
# ...

# %%
query2 = """
SELECT table1_data."Movie",table1_data."Director-1",table1_data."Director-2",table1_data."Director-3",table1_data."Director-4",table1_data."Director-5",table1_data."Director-6",table1_data."Rating",table2_data."Gross collection"
FROM table1_data 
JOIN table2_data ON table1_data."Movie" = table2_data."Movie" 
WHERE table2_data."Geners-1" = 'Action'
OR table2_data."Geners-2" = 'Action'
OR table2_data."Geners-3" = 'Action';
"""
result2 = pd.read_sql_query(query2 , conn)
print("Query2:")
print(result2)
# Out:
# Query2:
#                                                   Movie           Director-1  \
# 0                                       The Dark Knight    Christopher Nolan
# 1         The Lord of the Rings: The Return of the King        Peter Jackson
# 2                                             Inception    Christopher Nolan
# 3     The Lord of the Rings: The Fellowship of the Ring        Peter Jackson
# 4                 The Lord of the Rings: The Two Towers        Peter Jackson
# ...                                                 ...                  ...
# 1727      In the Name of the King: A Dungeon Siege Tale             Uwe Boll
# 1728                                       The Avengers  Jeremiah S. Chechik
# 1729                                       The Avengers          Joss Whedon
# 1730        The Adventures of Sharkboy and Lavagirl 3-D     Robert Rodriguez
# 1731                   Superman IV: The Quest for Peace      Sidney J. Furie
#
# ...

# %%
query3 = """
SELECT *
FROM table1_data 
JOIN table2_data ON table1_data."Movie" = table2_data."Movie"
WHERE table2_data."Gross collection" = (SELECT MAX("Gross collection") FROM table2_data);
"""
result3 = pd.read_sql_query(query3, conn)
print("Query 3:")
print(result3)
# Out:
# Query 3:
#   S no                                       Movie   Director-1 Director-2  \
# 0  143  Star Wars: Episode VII - The Force Awakens  J.J. Abrams       None
#
#   Director-3 Director-4 Director-5 Director-6  Duration  Year  ...  Geners-1  \
# 0       None       None       None       None       138  2015  ...    Action
#
#      Geners-2 Geners-3       Stars-1           Stars-2         Stars-3  \
# 0   Adventure   Sci-Fi  Hugo Weaving   Natalie Portman   Rupert Graves
#
#         Stars-4  Vottes Gross collection Certification
# 0   Stephen Rea  953123        936660000        PG-13
#
# [1 rows x 24 columns]

# %%
query4 = """
SELECT *
FROM table1_data
JOIN table2_data ON table1_data."Movie" = table2_data."Movie"
WHERE table1_data.Rating = (SELECT MAX(Rating) FROM table1_data);
"""
result4 = pd.read_sql_query(query4, conn)
print("Query 4:")
print(result4)
# Out:
# Query 4:
#   S no                                          Movie         Director-1  \
# 0    1                                The Dark Knight  Christopher Nolan
# 1    2  The Lord of the Rings: The Return of the King      Peter Jackson
#
#   Director-2 Director-3 Director-4 Director-5 Director-6  Duration  Year  ...  \
# 0       None       None       None       None       None       152  2008  ...
# 1       None       None       None       None       None       201  2003  ...
#
#    Geners-1    Geners-2 Geners-3         Stars-1           Stars-2  \
# 0    Action       Crime    Drama  Christian Bale      Heath Ledger
# 1    Action   Adventure    Drama     Elijah Wood   Viggo Mortensen
#
#           Stars-3         Stars-4   Vottes Gross collection Certification
# 0   Aaron Eckhart   Michael Caine  2757417        534860000        PG-13
# 1    Ian McKellen   Orlando Bloom  1905575        377850000        PG-13
#
# [2 rows x 24 columns]

# %%
query5 = """
SELECT *
FROM table1_data JOIN table2_data ON table1_data."Movie" = table2_data."Movie"
WHERE table2_data."Gross collection" = (SELECT MIN("Gross collection") FROM table2_data)
OR table1_data.Rating = (SELECT MIN(Rating) FROM table1_data);
"""
result5 = pd.read_sql_query(query5, conn)
print("Query 5:")
print(result5)
# Out:
# Query 5:
#     S no                                        Movie        Director-1  \
# 0    165                    Knockin' on Heaven's Door       Thomas Jahn
# 1    999                                 Son of a Gun      Julius Avery
# 2  1,312                                The Condemned       Scott Wiper
# 3  1,504                                    Wild Card        Simon West
# 4  1,749  The Adventures of Sharkboy and Lavagirl 3-D  Robert Rodriguez
# 5  1,750             Superman IV: The Quest for Peace   Sidney J. Furie
#
#   Director-2 Director-3 Director-4 Director-5 Director-6  Duration  Year  ...  \
# 0       None       None       None       None       None        87  1997  ...
# 1       None       None       None       None       None       108  2014  ...
# 2       None       None       None       None       None       113  2007  ...
# 3       None       None       None       None       None        92  2015  ...
# ...
